# %% [markdown]
# # Mock data

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
from math import exp,sin,cos
from pylab import *
from keras.models import load_model
from sklearn.preprocessing import scale
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
a=0.05
b=0.05
# took the liberty of reducing the max value for th 
# as it was giving you values of the order of e42
th=np.linspace(0, 40, 10000)  #creates 10000 equally spaces points between 0 to 40
x=10*a*exp(b*th)*cos(th) + 10
y=10*a*exp(b*th)*sin(th) + 10
z=10*th + 40  # creating the z array with the same length as th
ax.plot(x, y, z)  # adding z as an argument for the plot
ax.legend()
print(th)
plt.show()
# Out:
# No handles with labels found to put in legend.
# [0.00000000e+00 4.00040004e-03 8.00080008e-03 ... 3.99919992e+01
#  3.99959996e+01 4.00000000e+01]

# %%
import xlwt
import os
from xlwt import Workbook
#os.remove("ISRO.xls")
wb = Workbook()
sheet1 = wb.add_sheet('Sheet 1')
sheet1.write(0, 0, 'X Coordinate') 
sheet1.write(0, 1, 'Y Coordinate') 
sheet1.write(0, 2, 'z Coordinate')
sheet1.write(0, 3, 'Time')
for i in range(1,9990):
    sheet1.write(i, 0, x[i-1]) 
for j in range(1,9990):
    sheet1.write(j,1,y[j-1])
for k in range(1,9990):
    sheet1.write(k,2,z[k-1])
for t in range(1,9990):
    sheet1.write(t,3,t)
    
wb.save('ISRO.xls')

# %% [markdown]
# # Reshape data

# %%
x = np.reshape(x,(x.shape[0],1))
y = np.reshape(y,(y.shape[0],1))
z = np.reshape(z,(z.shape[0],1))
th = np.reshape(th,(th.shape[0],1))

# %% [markdown]
# # Normalize and Concatenate data

# %%
x = scale(x)
y = scale(y)
z = scale(z)
th = scale(th)

# %%
x_final = x[0:x.shape[0]-2,:]    #x before  x(t)                                                                      
y_final = y[0:y.shape[0]-2,:]
z_final = z[0:z.shape[0]-2,:]
th_final = th[1:th.shape[0]-1,:]

x_train_final = x[1:x.shape[0]-1,:] #x after; <-- this follows x final x(t+1)
y_train_final = y[1:y.shape[0]-1,:]
z_train_final = z[1:z.shape[0]-1,:]

# %%
xy = np.concatenate((x_final, y_final), axis=1)
xyz = np.concatenate((xy, z_final), axis=1)
X = np.concatenate((xyz, th_final), axis=1)

# %%
xy_train = np.concatenate((x_train_final, y_train_final), axis=1)
Y = np.concatenate((xy_train, z_train_final), axis=1)

# %% [markdown]
# ### sanity check

# %%
X.shape, Y.shape
# Out:
# ((9998, 4), (9998, 3))

# %% [markdown]
# # Split into train and test

# %%
train_X, train_Y = X[:8000,:], Y[:8000,:]
test_X, test_Y = X[8000:,:], Y[8000:,:]

# %%
train_X.shape, train_Y.shape, test_X.shape, test_Y.shape
# Out:
# ((8000, 4), (8000, 3), (1998, 4), (1998, 3))

# %% [markdown]
# # Model architecture

# %%
from keras.layers import Dense
from keras.layers import LSTM

from keras.models import Sequential

model = Sequential()

model.add(Dense(16, input_dim = 4, activation='relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(3))

model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /home/adityakishore/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Train model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(train_X,train_Y, validation_data=(test_X, test_Y), epochs=100, callbacks=[es, mc])
# Out:
# WARNING:tensorflow:From /home/adityakishore/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 8000 samples, validate on 1998 samples
# Epoch 1/100
# 8000/8000 [==============================] - 1s 172us/step - loss: 0.4396 - acc: 0.5142 - val_loss: 1.0945 - val_acc: 0.5791
#
# Epoch 00001: val_acc improved from -inf to 0.57908, saving model to best_model.h5
# Epoch 2/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.1739 - acc: 0.7931 - val_loss: 0.1685 - val_acc: 0.6572
#
# Epoch 00002: val_acc improved from 0.57908 to 0.65716, saving model to best_model.h5
# Epoch 3/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0181 - acc: 0.9100 - val_loss: 0.0673 - val_acc: 0.8589
#
# Epoch 00003: val_acc improved from 0.65716 to 0.85886, saving model to best_model.h5
# Epoch 4/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038 - acc: 0.9683 - val_loss: 0.0514 - val_acc: 0.8408
#
# Epoch 00004: val_acc did not improve from 0.85886
# Epoch 5/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0021 - acc: 0.9750 - val_loss: 0.0329 - val_acc: 0.9014
#
# Epoch 00005: val_acc improved from 0.85886 to 0.90140, saving model to best_model.h5
# Epoch 6/100
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0014 - acc: 0.9803 - val_loss: 0.0278 - val_acc: 0.9074
#
# Epoch 00006: val_acc improved from 0.90140 to 0.90741, saving model to best_model.h5
# Epoch 7/100
# 8000/8000 [==============================] - 0s 37us/step - loss: 8.6248e-04 - acc: 0.9864 - val_loss: 0.0184 - val_acc: 0.9389
#
# Epoch 00007: val_acc improved from 0.90741 to 0.93894, saving model to best_model.h5
# Epoch 8/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 5.4826e-04 - acc: 0.9908 - val_loss: 0.0151 - val_acc: 0.9494
#
# Epoch 00008: val_acc improved from 0.93894 to 0.94945, saving model to best_model.h5
# Epoch 9/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 3.9024e-04 - acc: 0.9920 - val_loss: 0.0135 - val_acc: 0.9565
#
# Epoch 00009: val_acc improved from 0.94945 to 0.95646, saving model to best_model.h5
# Epoch 10/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 2.9863e-04 - acc: 0.9925 - val_loss: 0.0118 - val_acc: 0.9645
#
# Epoch 00010: val_acc improved from 0.95646 to 0.96446, saving model to best_model.h5
# Epoch 11/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 2.4248e-04 - acc: 0.9939 - val_loss: 0.0097 - val_acc: 0.9745
#
# Epoch 00011: val_acc improved from 0.96446 to 0.97447, saving model to best_model.h5
# Epoch 12/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 2.0547e-04 - acc: 0.9944 - val_loss: 0.0091 - val_acc: 0.9740
#
# Epoch 00012: val_acc did not improve from 0.97447
# Epoch 13/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 1.8290e-04 - acc: 0.9944 - val_loss: 0.0080 - val_acc: 0.9795
#
# Epoch 00013: val_acc improved from 0.97447 to 0.97948, saving model to best_model.h5
# Epoch 14/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 1.5897e-04 - acc: 0.9948 - val_loss: 0.0068 - val_acc: 0.9815
#
# Epoch 00014: val_acc improved from 0.97948 to 0.98148, saving model to best_model.h5
# Epoch 15/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 1.3880e-04 - acc: 0.9951 - val_loss: 0.0062 - val_acc: 0.9835
#
# Epoch 00015: val_acc improved from 0.98148 to 0.98348, saving model to best_model.h5
# Epoch 16/100
# 8000/8000 [==============================] - 0s 50us/step - loss: 1.2117e-04 - acc: 0.9954 - val_loss: 0.0061 - val_acc: 0.9815
#
# Epoch 00016: val_acc did not improve from 0.98348
# Epoch 17/100
# 8000/8000 [==============================] - 0s 42us/step - loss: 1.0428e-04 - acc: 0.9952 - val_loss: 0.0045 - val_acc: 0.9855
#
# Epoch 00017: val_acc improved from 0.98348 to 0.98549, saving model to best_model.h5
# Epoch 18/100
# 8000/8000 [==============================] - 0s 43us/step - loss: 8.9009e-05 - acc: 0.9957 - val_loss: 0.0042 - val_acc: 0.9850
#
# Epoch 00018: val_acc did not improve from 0.98549
# Epoch 19/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 7.6176e-05 - acc: 0.9954 - val_loss: 0.0038 - val_acc: 0.9855
#
# Epoch 00019: val_acc did not improve from 0.98549
# Epoch 20/100
# 8000/8000 [==============================] - 0s 48us/step - loss: 6.6412e-05 - acc: 0.9955 - val_loss: 0.0033 - val_acc: 0.9875
#
# Epoch 00020: val_acc improved from 0.98549 to 0.98749, saving model to best_model.h5
# Epoch 21/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 5.8638e-05 - acc: 0.9966 - val_loss: 0.0027 - val_acc: 0.9875
#
# Epoch 00021: val_acc did not improve from 0.98749
# Epoch 22/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 5.3035e-05 - acc: 0.9971 - val_loss: 0.0031 - val_acc: 0.9875
#
# Epoch 00022: val_acc did not improve from 0.98749
# Epoch 23/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 4.7241e-05 - acc: 0.9962 - val_loss: 0.0030 - val_acc: 0.9865
#
# Epoch 00023: val_acc did not improve from 0.98749
# Epoch 24/100
# 8000/8000 [==============================] - 0s 37us/step - loss: 4.2535e-05 - acc: 0.9973 - val_loss: 0.0024 - val_acc: 0.9905
#
# Epoch 00024: val_acc improved from 0.98749 to 0.99049, saving model to best_model.h5
# Epoch 25/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 3.7875e-05 - acc: 0.9971 - val_loss: 0.0021 - val_acc: 0.9905
#
# Epoch 00025: val_acc did not improve from 0.99049
# Epoch 26/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 3.3985e-05 - acc: 0.9976 - val_loss: 0.0019 - val_acc: 0.9905
#
# Epoch 00026: val_acc did not improve from 0.99049
# Epoch 27/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 2.9733e-05 - acc: 0.9975 - val_loss: 0.0021 - val_acc: 0.9895
#
# Epoch 00027: val_acc did not improve from 0.99049
# Epoch 28/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 2.9062e-05 - acc: 0.9975 - val_loss: 0.0019 - val_acc: 0.9910
#
# Epoch 00028: val_acc improved from 0.99049 to 0.99099, saving model to best_model.h5
# Epoch 29/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 2.5403e-05 - acc: 0.9983 - val_loss: 0.0016 - val_acc: 0.9915
#
# Epoch 00029: val_acc improved from 0.99099 to 0.99149, saving model to best_model.h5
# Epoch 30/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 2.3656e-05 - acc: 0.9981 - val_loss: 0.0015 - val_acc: 0.9920
#
# Epoch 00030: val_acc improved from 0.99149 to 0.99199, saving model to best_model.h5
# Epoch 31/100
# 8000/8000 [==============================] - 0s 48us/step - loss: 2.0242e-05 - acc: 0.9978 - val_loss: 0.0015 - val_acc: 0.9915
#
# Epoch 00031: val_acc did not improve from 0.99199
# Epoch 32/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 1.8189e-05 - acc: 0.9985 - val_loss: 0.0013 - val_acc: 0.9925
#
# Epoch 00032: val_acc improved from 0.99199 to 0.99249, saving model to best_model.h5
# Epoch 33/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 1.6881e-05 - acc: 0.9989 - val_loss: 0.0011 - val_acc: 0.9935
#
# Epoch 00033: val_acc improved from 0.99249 to 0.99349, saving model to best_model.h5
# Epoch 34/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 1.7142e-05 - acc: 0.9988 - val_loss: 0.0012 - val_acc: 0.9925
#
# Epoch 00034: val_acc did not improve from 0.99349
# Epoch 35/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 1.4512e-05 - acc: 0.9983 - val_loss: 9.3883e-04 - val_acc: 0.9945
#
# Epoch 00035: val_acc improved from 0.99349 to 0.99449, saving model to best_model.h5
# Epoch 36/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 1.3811e-05 - acc: 0.9986 - val_loss: 9.4814e-04 - val_acc: 0.9935
#
# Epoch 00036: val_acc did not improve from 0.99449
# Epoch 37/100
# 8000/8000 [==============================] - 0s 42us/step - loss: 1.4177e-05 - acc: 0.9984 - val_loss: 9.0473e-04 - val_acc: 0.9945
#
# Epoch 00037: val_acc did not improve from 0.99449
# Epoch 38/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 1.2539e-05 - acc: 0.9995 - val_loss: 7.9708e-04 - val_acc: 0.9950
#
# Epoch 00038: val_acc improved from 0.99449 to 0.99499, saving model to best_model.h5
# Epoch 39/100
# 8000/8000 [==============================] - 0s 35us/step - loss: 1.1512e-05 - acc: 0.9992 - val_loss: 7.7424e-04 - val_acc: 0.9940
#
# Epoch 00039: val_acc did not improve from 0.99499
# Epoch 40/100
# 8000/8000 [==============================] - 0s 37us/step - loss: 1.0563e-05 - acc: 0.9985 - val_loss: 7.2416e-04 - val_acc: 0.9945
#
# Epoch 00040: val_acc did not improve from 0.99499
# Epoch 41/100
# 8000/8000 [==============================] - 0s 36us/step - loss: 8.9514e-06 - acc: 0.9992 - val_loss: 7.3411e-04 - val_acc: 0.9950
#
# Epoch 00041: val_acc did not improve from 0.99499
# Epoch 42/100
# 8000/8000 [==============================] - 0s 35us/step - loss: 9.0144e-06 - acc: 0.9985 - val_loss: 6.5350e-04 - val_acc: 0.9945
#
# Epoch 00042: val_acc did not improve from 0.99499
# Epoch 43/100
# 8000/8000 [==============================] - 0s 46us/step - loss: 8.9533e-06 - acc: 0.9985 - val_loss: 5.7163e-04 - val_acc: 0.9955
#
# Epoch 00043: val_acc improved from 0.99499 to 0.99550, saving model to best_model.h5
# Epoch 44/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 7.1194e-06 - acc: 0.9989 - val_loss: 5.3300e-04 - val_acc: 0.9955
#
# Epoch 00044: val_acc did not improve from 0.99550
# Epoch 45/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 6.2247e-06 - acc: 0.9992 - val_loss: 4.6434e-04 - val_acc: 0.9960
#
# Epoch 00045: val_acc improved from 0.99550 to 0.99600, saving model to best_model.h5
# Epoch 46/100
# 8000/8000 [==============================] - 0s 47us/step - loss: 6.9507e-06 - acc: 0.9989 - val_loss: 4.8299e-04 - val_acc: 0.9960
#
# Epoch 00046: val_acc did not improve from 0.99600
# Epoch 47/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 1.5681e-05 - acc: 0.9986 - val_loss: 4.5809e-04 - val_acc: 0.9955
#
# Epoch 00047: val_acc did not improve from 0.99600
# Epoch 48/100
# 8000/8000 [==============================] - 0s 50us/step - loss: 5.3013e-06 - acc: 0.9994 - val_loss: 4.2528e-04 - val_acc: 0.9965
#
# Epoch 00048: val_acc improved from 0.99600 to 0.99650, saving model to best_model.h5
# Epoch 49/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 4.7687e-06 - acc: 0.9996 - val_loss: 4.2477e-04 - val_acc: 0.9965
#
# Epoch 00049: val_acc did not improve from 0.99650
# Epoch 50/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 4.6737e-06 - acc: 0.9995 - val_loss: 4.5547e-04 - val_acc: 0.9975
#
# Epoch 00050: val_acc improved from 0.99650 to 0.99750, saving model to best_model.h5
# Epoch 51/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 4.5548e-06 - acc: 0.9989 - val_loss: 4.1309e-04 - val_acc: 0.9970
#
# Epoch 00051: val_acc did not improve from 0.99750
# Epoch 52/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 4.1166e-06 - acc: 0.9992 - val_loss: 3.9845e-04 - val_acc: 0.9960
#
# Epoch 00052: val_acc did not improve from 0.99750
# Epoch 53/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 3.6207e-06 - acc: 0.9994 - val_loss: 3.3059e-04 - val_acc: 0.9980
#
# Epoch 00053: val_acc improved from 0.99750 to 0.99800, saving model to best_model.h5
# Epoch 54/100
# 8000/8000 [==============================] - 0s 51us/step - loss: 4.8885e-06 - acc: 0.9989 - val_loss: 2.9332e-04 - val_acc: 0.9980
#
# Epoch 00054: val_acc did not improve from 0.99800
# Epoch 55/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 4.9877e-06 - acc: 0.9992 - val_loss: 3.9580e-04 - val_acc: 0.9970
#
# Epoch 00055: val_acc did not improve from 0.99800
# Epoch 56/100
# 8000/8000 [==============================] - 0s 47us/step - loss: 3.6078e-06 - acc: 0.9992 - val_loss: 3.4697e-04 - val_acc: 0.9970
#
# Epoch 00056: val_acc did not improve from 0.99800
# Epoch 57/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 6.6119e-06 - acc: 0.9986 - val_loss: 3.1730e-04 - val_acc: 0.9975
#
# Epoch 00057: val_acc did not improve from 0.99800
# Epoch 58/100
# 8000/8000 [==============================] - 0s 47us/step - loss: 3.2493e-06 - acc: 0.9989 - val_loss: 2.6954e-04 - val_acc: 0.9980
#
# Epoch 00058: val_acc did not improve from 0.99800
# Epoch 59/100
# 8000/8000 [==============================] - 0s 46us/step - loss: 3.5253e-06 - acc: 0.9996 - val_loss: 2.9465e-04 - val_acc: 0.9980
#
# Epoch 00059: val_acc did not improve from 0.99800
# Epoch 60/100
# 8000/8000 [==============================] - 0s 43us/step - loss: 2.9092e-06 - acc: 0.9994 - val_loss: 2.7634e-04 - val_acc: 0.9970
#
# Epoch 00060: val_acc did not improve from 0.99800
# Epoch 61/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 5.6953e-06 - acc: 0.9991 - val_loss: 2.8478e-04 - val_acc: 0.9970
#
# Epoch 00061: val_acc did not improve from 0.99800
# Epoch 62/100
# 8000/8000 [==============================] - 0s 38us/step - loss: 3.2404e-06 - acc: 0.9994 - val_loss: 2.6672e-04 - val_acc: 0.9970
#
# Epoch 00062: val_acc did not improve from 0.99800
# Epoch 63/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 2.8032e-06 - acc: 0.9989 - val_loss: 2.6381e-04 - val_acc: 0.9975
#
# Epoch 00063: val_acc did not improve from 0.99800
# Epoch 64/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 4.5246e-06 - acc: 0.9990 - val_loss: 2.6581e-04 - val_acc: 0.9970
#
# Epoch 00064: val_acc did not improve from 0.99800
# Epoch 65/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 2.5295e-06 - acc: 0.9990 - val_loss: 2.3536e-04 - val_acc: 0.9980
#
# Epoch 00065: val_acc did not improve from 0.99800
# Epoch 66/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 2.4875e-06 - acc: 0.9994 - val_loss: 2.3372e-04 - val_acc: 0.9970
#
# Epoch 00066: val_acc did not improve from 0.99800
# Epoch 67/100
# 8000/8000 [==============================] - 0s 37us/step - loss: 8.7546e-06 - acc: 0.9986 - val_loss: 2.4403e-04 - val_acc: 0.9975
#
# Epoch 00067: val_acc did not improve from 0.99800
# Epoch 68/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 1.5778e-06 - acc: 0.9995 - val_loss: 2.1516e-04 - val_acc: 0.9975
#
# Epoch 00068: val_acc did not improve from 0.99800
# Epoch 69/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 1.4321e-06 - acc: 0.9996 - val_loss: 2.0922e-04 - val_acc: 0.9975
#
# Epoch 00069: val_acc did not improve from 0.99800
# Epoch 70/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 1.9239e-06 - acc: 0.9992 - val_loss: 2.2478e-04 - val_acc: 0.9970
#
# Epoch 00070: val_acc did not improve from 0.99800
# Epoch 71/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 2.4021e-06 - acc: 0.9991 - val_loss: 2.0290e-04 - val_acc: 0.9980
#
# Epoch 00071: val_acc did not improve from 0.99800
# Epoch 72/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 3.8216e-06 - acc: 0.9989 - val_loss: 2.1475e-04 - val_acc: 0.9975
#
# Epoch 00072: val_acc did not improve from 0.99800
# Epoch 73/100
# 8000/8000 [==============================] - 0s 46us/step - loss: 1.4606e-06 - acc: 0.9994 - val_loss: 2.3615e-04 - val_acc: 0.9975
#
# Epoch 00073: val_acc did not improve from 0.99800
# Epoch 74/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 9.1547e-06 - acc: 0.9986 - val_loss: 2.1020e-04 - val_acc: 0.9975
#
# Epoch 00074: val_acc did not improve from 0.99800
# Epoch 75/100
# 8000/8000 [==============================] - 1s 67us/step - loss: 1.2243e-06 - acc: 0.9998 - val_loss: 1.9228e-04 - val_acc: 0.9980
#
# Epoch 00075: val_acc did not improve from 0.99800
# Epoch 76/100
# 8000/8000 [==============================] - 0s 58us/step - loss: 1.0902e-06 - acc: 0.9996 - val_loss: 1.6935e-04 - val_acc: 0.9975
#
# Epoch 00076: val_acc did not improve from 0.99800
# Epoch 77/100
# 8000/8000 [==============================] - 0s 43us/step - loss: 1.1085e-06 - acc: 0.9999 - val_loss: 1.8244e-04 - val_acc: 0.9975
#
# Epoch 00077: val_acc did not improve from 0.99800
# Epoch 78/100
# 8000/8000 [==============================] - 0s 42us/step - loss: 6.5520e-06 - acc: 0.9986 - val_loss: 1.8228e-04 - val_acc: 0.9975
#
# Epoch 00078: val_acc did not improve from 0.99800
# Epoch 79/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 8.2423e-07 - acc: 0.9998 - val_loss: 1.7653e-04 - val_acc: 0.9975
#
# Epoch 00079: val_acc did not improve from 0.99800
# Epoch 80/100
# 8000/8000 [==============================] - 0s 36us/step - loss: 9.5901e-07 - acc: 0.9996 - val_loss: 1.6351e-04 - val_acc: 0.9975
#
# Epoch 00080: val_acc did not improve from 0.99800
# Epoch 81/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 1.4984e-06 - acc: 0.9994 - val_loss: 1.6448e-04 - val_acc: 0.9975
#
# Epoch 00081: val_acc did not improve from 0.99800
# Epoch 82/100
# 8000/8000 [==============================] - 0s 37us/step - loss: 8.1318e-06 - acc: 0.9988 - val_loss: 1.7613e-04 - val_acc: 0.9975
#
# Epoch 00082: val_acc did not improve from 0.99800
# Epoch 83/100
# 8000/8000 [==============================] - 0s 57us/step - loss: 6.4640e-07 - acc: 0.9998 - val_loss: 1.6265e-04 - val_acc: 0.9975
#
# Epoch 00083: val_acc did not improve from 0.99800
# Epoch 84/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 7.0643e-07 - acc: 1.0000 - val_loss: 1.7860e-04 - val_acc: 0.9975
#
# Epoch 00084: val_acc did not improve from 0.99800
# Epoch 85/100
# 8000/8000 [==============================] - 0s 37us/step - loss: 4.8391e-06 - acc: 0.9994 - val_loss: 1.8079e-04 - val_acc: 0.9970
#
# Epoch 00085: val_acc did not improve from 0.99800
# Epoch 86/100
# 8000/8000 [==============================] - 0s 52us/step - loss: 1.3117e-06 - acc: 0.9992 - val_loss: 1.6032e-04 - val_acc: 0.9970
#
# Epoch 00086: val_acc did not improve from 0.99800
# Epoch 87/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 2.1789e-06 - acc: 0.9998 - val_loss: 1.6736e-04 - val_acc: 0.9965
#
# Epoch 00087: val_acc did not improve from 0.99800
# Epoch 88/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 1.4940e-06 - acc: 0.9996 - val_loss: 1.6389e-04 - val_acc: 0.9970
#
# Epoch 00088: val_acc did not improve from 0.99800
# Epoch 89/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 2.1077e-06 - acc: 0.9994 - val_loss: 1.3783e-04 - val_acc: 0.9980
#
# Epoch 00089: val_acc did not improve from 0.99800
# Epoch 90/100
# 8000/8000 [==============================] - 0s 47us/step - loss: 2.0835e-06 - acc: 0.9996 - val_loss: 2.7605e-04 - val_acc: 0.9955
#
# Epoch 00090: val_acc did not improve from 0.99800
# Epoch 91/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 1.7110e-06 - acc: 0.9991 - val_loss: 1.7865e-04 - val_acc: 0.9965
#
# Epoch 00091: val_acc did not improve from 0.99800
# Epoch 92/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 8.4907e-07 - acc: 0.9996 - val_loss: 1.6739e-04 - val_acc: 0.9970
#
# Epoch 00092: val_acc did not improve from 0.99800
# Epoch 93/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 4.8064e-06 - acc: 0.9991 - val_loss: 1.7107e-04 - val_acc: 0.9970
#
# Epoch 00093: val_acc did not improve from 0.99800
# Epoch 94/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 1.5547e-06 - acc: 0.9992 - val_loss: 1.4487e-04 - val_acc: 0.9965
#
# Epoch 00094: val_acc did not improve from 0.99800
# Epoch 95/100
# 8000/8000 [==============================] - 0s 51us/step - loss: 5.3174e-07 - acc: 0.9999 - val_loss: 1.5969e-04 - val_acc: 0.9965
#
# Epoch 00095: val_acc did not improve from 0.99800
# Epoch 96/100
# 8000/8000 [==============================] - 0s 46us/step - loss: 1.5065e-06 - acc: 0.9996 - val_loss: 1.4403e-04 - val_acc: 0.9970
#
# Epoch 00096: val_acc did not improve from 0.99800
# Epoch 97/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 5.9775e-06 - acc: 0.9991 - val_loss: 1.4271e-04 - val_acc: 0.9965
#
# Epoch 00097: val_acc did not improve from 0.99800
# Epoch 98/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 7.0486e-07 - acc: 0.9995 - val_loss: 1.4033e-04 - val_acc: 0.9970
#
# Epoch 00098: val_acc did not improve from 0.99800
# Epoch 99/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 3.7308e-07 - acc: 0.9999 - val_loss: 1.2332e-04 - val_acc: 0.9970
#
# Epoch 00099: val_acc did not improve from 0.99800
# Epoch 100/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 6.8205e-06 - acc: 0.9991 - val_loss: 1.3159e-04 - val_acc: 0.9970
#
# Epoch 00100: val_acc did not improve from 0.99800

# %% [markdown]
# # Evaluate Model

# %%
saved_model = load_model('best_model.h5')
_, train_acc = saved_model.evaluate(train_X, train_Y, verbose=0)
_, test_acc = saved_model.evaluate(test_X, test_Y, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc*100, test_acc*100))
# Out:
# Train: 99.913, Test: 99.800

# %% [markdown]
# # Plot model

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()
